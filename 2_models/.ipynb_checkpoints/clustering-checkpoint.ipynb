# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/76/e8/260752c1bc8dc856b27cfefaa3fca29ba02a15f649bbf6e9c15ed54e5480/xgboost-2.0.2-py3-none-macosx_12_0_arm64.whl.metadata
#   Downloading xgboost-2.0.2-py3-none-macosx_12_0_arm64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in /Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages (from xgboost) (1.11.1)
# Downloading xgboost-2.0.2-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import sklearn
import xgboost

# %%
df = pd.read_csv("../../clean_data/final_df.csv", index_col=0)

# %%
df.head()
# Out:
#   Company                Device      Market       SubMarket  Year      Value  \
# 0     ABB  Amplifier/Comparator  Industrial  Power & Energy  2018   7.466000
# 1     ABB  Amplifier/Comparator  Industrial  Power & Energy  2019   8.471900
# 2     ABB  Amplifier/Comparator  Industrial  Power & Energy  2020   8.661150
# 3     ABB  Amplifier/Comparator  Industrial  Power & Energy  2021  10.090255
# 4     ABB  Amplifier/Comparator  Industrial  Power & Energy  2022  10.040442
#
#                                          Region  Spendings   DevSpends  \
# 0  AmericasAsia & Oceania (exc. Japan)EMEAJapan    200.530  172603.835
# 1  AmericasAsia & Oceania (exc. Japan)EMEAJapan    189.490  163733.518
# 2  AmericasAsia & Oceania (exc. Japan)EMEAJapan    195.081  163007.011
# 3  AmericasAsia & Oceania (exc. Japan)EMEAJapan    240.245  212172.612
# 4  AmericasAsia & Oceania (exc. Japan)EMEAJapan    257.635  242620.053
#
#    MarketSpends  SubMarketSpends     Cogs   Cogs_1   Cogs_2  Revenue  \
# 0    744408.882        59122.300  19059.0  17278.0  17270.0  27662.0
# 1    694336.713        56477.645  19018.0  19059.0  17278.0  27978.0
# 2    715358.270        58137.779  18123.0  19018.0  19059.0  26134.0
# 3    898036.093        67325.066  19407.0  18123.0  19018.0  28945.0
# 4   1010453.110        73245.445  19712.0  19407.0  18123.0  29446.0
#
#    Revenue_1  Revenue_2  Ebitda  Ebitda_1  Ebitda_2
# 0    25196.0    24929.0  3227.0    2929.0    2987.0
# 1    27662.0    25196.0  3347.0    3227.0    2929.0
# 2    27978.0    27662.0  2668.0    3347.0    3227.0
# 3    26134.0    27978.0  4641.0    2668.0    3347.0
# 4    28945.0    26134.0  4477.0    4641.0    2668.0

# %%
df.rename({"Value":"CompanySpend", "Spendings":"TotalSpend"}, axis=1, inplace=True)

# %%
df= pd.get_dummies(df, columns=["Device", "Market", "SubMarket"])

# %%
df.head()
# Out:
#   Company  Year  CompanySpend                                        Region  \
# 0     ABB  2018      7.466000  AmericasAsia & Oceania (exc. Japan)EMEAJapan
# 1     ABB  2019      8.471900  AmericasAsia & Oceania (exc. Japan)EMEAJapan
# 2     ABB  2020      8.661150  AmericasAsia & Oceania (exc. Japan)EMEAJapan
# 3     ABB  2021     10.090255  AmericasAsia & Oceania (exc. Japan)EMEAJapan
# 4     ABB  2022     10.040442  AmericasAsia & Oceania (exc. Japan)EMEAJapan
#
#    TotalSpend   DevSpends  MarketSpends  SubMarketSpends     Cogs   Cogs_1  \
# 0     200.530  172603.835    744408.882        59122.300  19059.0  17278.0
# 1     189.490  163733.518    694336.713        56477.645  19018.0  19059.0
# 2     195.081  163007.011    715358.270        58137.779  18123.0  19018.0
# 3     240.245  212172.612    898036.093        67325.066  19407.0  18123.0
# 4     257.635  242620.053   1010453.110        73245.445  19712.0  19407.0
#
#    ...  SubMarket_Other Peripherals  SubMarket_Other Storage  \
# 0  ...                        False                    False
# 1  ...                        False                    False
# 2  ...                        False                    False
# 3  ...                        False                    False
# 4  ...                        False                    False
#
#    SubMarket_Other Wired  SubMarket_Other Wireless  SubMarket_Power & Energy  \
# 0                  False                     False                      True
# 1                  False                     False                      True
# 2                  False                     False                      True
# 3                  False                     False                      True
# 4                  False                     False                      True
#
#    SubMarket_STB  SubMarket_TV  SubMarket_Tablet PCs  \
# 0          False         False                 False
# 1          False         False                 False
# 2          False         False                 False
# 3          False         False                 False
# 4          False         False                 False
#
#    SubMarket_Test & Measurement  SubMarket_Video Games
# 0                         False                  False
# 1                         False                  False
# 2                         False                  False
# 3                         False                  False
# 4                         False                  False
#
# [5 rows x 62 columns]

# %%
X_train = df[(df.Year<=2022)]
X_test = df[(df.Year>=2023)]
y_train = X_train.pop("CompanySpend")
y_test = X_test.pop("CompanySpend")
X_train.drop(["Company", "Year"], axis=1, inplace=True)
X_test.drop(["Company", "Year"], axis=1, inplace=True)
# Out:
# /var/folders/px/tjlhxsg56bg6d74d3c4cnhrc0000gn/T/ipykernel_60791/3952824684.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.drop(["Company", "Year"], axis=1, inplace=True)
# /var/folders/px/tjlhxsg56bg6d74d3c4cnhrc0000gn/T/ipykernel_60791/3952824684.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.drop(["Company", "Year"], axis=1, inplace=True)

# %%
y_train
# Out:
# 0         7.466000
# 1         8.471900
# 2         8.661150
# 3        10.090255
# 4        10.040442
#            ...
# 25930     5.267500
# 25931     7.301500
# 25932    10.295800
# 25933    17.639800
# 25934    23.717500
# Name: CompanySpend, Length: 17768, dtype: float64

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
model_xgb = xgb.XGBRegressor(verbosity=2, device="cuda")

# %%
parameters = {'learning_rate': np.arange(0.001, 0.1, 0.005), 
              'max_depth': [4, 5, 6, 7, 8],
              'min_child_weight': [1, 2, 3, 4, 5],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [100, 200, 300, 500],
              'alpha': np.arange(0, 2, 0.1),
              'lambda' : np.arange(0,2,0.1)}

xgb_grid = RandomizedSearchCV(model_xgb,
                        parameters,
                        cv = 4,
                        n_jobs = 1,
                        verbose=3,
                        n_iter = 500)

# %%
xgb_grid.fit(X_train,
         y_train)
# Out:
# Fitting 4 folds for each of 500 candidates, totalling 2000 fits
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.076, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.076, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.076, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.076, max_depth=8, min_child_weight=1, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.041, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.041, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.041, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.041, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.5, colsample_bytree=0.7, lambda=1.2000000000000002, learning_rate=0.091, max_depth=6, min_child_weight=2, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.5, colsample_bytree=0.7, lambda=1.2000000000000002, learning_rate=0.091, max_depth=6, min_child_weight=2, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.5, colsample_bytree=0.7, lambda=1.2000000000000002, learning_rate=0.091, max_depth=6, min_child_weight=2, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.5, colsample_bytree=0.7, lambda=1.2000000000000002, learning_rate=0.091, max_depth=6, min_child_weight=2, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.2, learning_rate=0.081, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.2, learning_rate=0.081, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.2, learning_rate=0.081, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.2, learning_rate=0.081, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.031, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.031, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.031, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.031, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=0.8, learning_rate=0.081, max_depth=7, min_child_weight=5, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=0.8, learning_rate=0.081, max_depth=7, min_child_weight=5, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=0.8, learning_rate=0.081, max_depth=7, min_child_weight=5, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=0.8, learning_rate=0.081, max_depth=7, min_child_weight=5, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.6, learning_rate=0.016, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.6, learning_rate=0.016, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.6, learning_rate=0.016, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.6, learning_rate=0.016, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.4, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.046, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.4, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.046, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.4, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.046, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.4, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.046, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.0, learning_rate=0.066, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.0, learning_rate=0.066, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.0, learning_rate=0.066, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.0, learning_rate=0.066, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.4, learning_rate=0.011, max_depth=6, min_child_weight=3, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.4, learning_rate=0.011, max_depth=6, min_child_weight=3, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.4, learning_rate=0.011, max_depth=6, min_child_weight=3, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.4, learning_rate=0.011, max_depth=6, min_child_weight=3, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.061, max_depth=6, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.061, max_depth=6, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.061, max_depth=6, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.061, max_depth=6, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.046, max_depth=6, min_child_weight=1, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.046, max_depth=6, min_child_weight=1, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.046, max_depth=6, min_child_weight=1, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.046, max_depth=6, min_child_weight=1, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=0.8, learning_rate=0.011, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=0.8, learning_rate=0.011, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=0.8, learning_rate=0.011, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=0.8, learning_rate=0.011, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.051000000000000004, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.051000000000000004, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.051000000000000004, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.051000000000000004, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.076, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.076, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.076, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.076, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.8, learning_rate=0.061, max_depth=6, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.8, learning_rate=0.061, max_depth=6, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.8, learning_rate=0.061, max_depth=6, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.8, learning_rate=0.061, max_depth=6, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.2, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.076, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.2, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.076, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.2, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.076, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.2, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.076, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.011, max_depth=7, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.011, max_depth=7, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.011, max_depth=7, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.011, max_depth=7, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.1, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.011, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.1, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.011, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.1, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.011, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.1, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.011, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.5, learning_rate=0.081, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.5, learning_rate=0.081, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.5, learning_rate=0.081, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.5, learning_rate=0.081, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.9, learning_rate=0.041, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.9, learning_rate=0.041, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.9, learning_rate=0.041, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.9, learning_rate=0.041, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.091, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.091, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.091, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.091, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.2, learning_rate=0.031, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.2, learning_rate=0.031, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.2, learning_rate=0.031, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.6, colsample_bytree=0.7, lambda=0.2, learning_rate=0.031, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.026000000000000002, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.026000000000000002, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.026000000000000002, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.9000000000000001, learning_rate=0.026000000000000002, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.036000000000000004, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.036000000000000004, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.036000000000000004, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.036000000000000004, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.0, learning_rate=0.021, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.0, learning_rate=0.021, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.0, learning_rate=0.021, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.0, learning_rate=0.021, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.07100000000000001, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.07100000000000001, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.07100000000000001, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.07100000000000001, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=1.8, learning_rate=0.081, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=1.8, learning_rate=0.081, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=1.8, learning_rate=0.081, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=1.8, learning_rate=0.081, max_depth=5, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=1.6, learning_rate=0.056, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=1.6, learning_rate=0.056, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=1.6, learning_rate=0.056, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=1.6, learning_rate=0.056, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.3, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.081, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.3, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.081, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.3, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.081, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.3, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.081, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=0.9, learning_rate=0.041, max_depth=6, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=0.9, learning_rate=0.041, max_depth=6, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=0.9, learning_rate=0.041, max_depth=6, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=0.9, learning_rate=0.041, max_depth=6, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.2, learning_rate=0.066, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.2, learning_rate=0.066, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.2, learning_rate=0.066, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.2, learning_rate=0.066, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.096, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.096, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.096, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=1.7000000000000002, learning_rate=0.096, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.1, colsample_bytree=0.7, lambda=0.8, learning_rate=0.07100000000000001, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.1, colsample_bytree=0.7, lambda=0.8, learning_rate=0.07100000000000001, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.1, colsample_bytree=0.7, lambda=0.8, learning_rate=0.07100000000000001, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.1, colsample_bytree=0.7, lambda=0.8, learning_rate=0.07100000000000001, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.2, learning_rate=0.056, max_depth=4, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.2, learning_rate=0.056, max_depth=4, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.2, learning_rate=0.056, max_depth=4, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.2, learning_rate=0.056, max_depth=4, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.4, learning_rate=0.026000000000000002, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.4, learning_rate=0.026000000000000002, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.4, learning_rate=0.026000000000000002, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.2, colsample_bytree=0.7, lambda=0.4, learning_rate=0.026000000000000002, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.9, colsample_bytree=0.7, lambda=0.4, learning_rate=0.076, max_depth=7, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.9, colsample_bytree=0.7, lambda=0.4, learning_rate=0.076, max_depth=7, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.9, colsample_bytree=0.7, lambda=0.4, learning_rate=0.076, max_depth=7, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.9, colsample_bytree=0.7, lambda=0.4, learning_rate=0.076, max_depth=7, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.5, learning_rate=0.041, max_depth=7, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.5, learning_rate=0.041, max_depth=7, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.5, learning_rate=0.041, max_depth=7, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.5, learning_rate=0.041, max_depth=7, min_child_weight=4, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.0, learning_rate=0.056, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.0, learning_rate=0.056, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.0, learning_rate=0.056, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.0, learning_rate=0.056, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=0.8, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=0.8, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=0.8, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=0.8, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.5, colsample_bytree=0.7, lambda=0.4, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.5, colsample_bytree=0.7, lambda=0.4, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.5, colsample_bytree=0.7, lambda=0.4, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.5, colsample_bytree=0.7, lambda=0.4, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=1.8, learning_rate=0.021, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=1.8, learning_rate=0.021, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=1.8, learning_rate=0.021, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=1.8, learning_rate=0.021, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.08600000000000001, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.08600000000000001, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.08600000000000001, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.4000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.08600000000000001, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.2000000000000002, learning_rate=0.006, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.2000000000000002, learning_rate=0.006, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.2000000000000002, learning_rate=0.006, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.1, colsample_bytree=0.7, lambda=1.2000000000000002, learning_rate=0.006, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.5, learning_rate=0.096, max_depth=6, min_child_weight=1, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.5, learning_rate=0.096, max_depth=6, min_child_weight=1, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.5, learning_rate=0.096, max_depth=6, min_child_weight=1, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.5, learning_rate=0.096, max_depth=6, min_child_weight=1, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.096, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.096, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.096, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.8, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.096, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.1, colsample_bytree=0.7, lambda=0.5, learning_rate=0.091, max_depth=4, min_child_weight=5, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.1, colsample_bytree=0.7, lambda=0.5, learning_rate=0.091, max_depth=4, min_child_weight=5, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.1, colsample_bytree=0.7, lambda=0.5, learning_rate=0.091, max_depth=4, min_child_weight=5, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.1, colsample_bytree=0.7, lambda=0.5, learning_rate=0.091, max_depth=4, min_child_weight=5, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.8, colsample_bytree=0.7, lambda=1.3, learning_rate=0.036000000000000004, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.8, colsample_bytree=0.7, lambda=1.3, learning_rate=0.036000000000000004, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.8, colsample_bytree=0.7, lambda=1.3, learning_rate=0.036000000000000004, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.8, colsample_bytree=0.7, lambda=1.3, learning_rate=0.036000000000000004, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.5, colsample_bytree=0.7, lambda=1.4000000000000001, learning_rate=0.056, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.5, colsample_bytree=0.7, lambda=1.4000000000000001, learning_rate=0.056, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.5, colsample_bytree=0.7, lambda=1.4000000000000001, learning_rate=0.056, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.5, colsample_bytree=0.7, lambda=1.4000000000000001, learning_rate=0.056, max_depth=7, min_child_weight=2, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.091, max_depth=8, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.091, max_depth=8, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.091, max_depth=8, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.2000000000000002, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.091, max_depth=8, min_child_weight=4, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.1, learning_rate=0.066, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.1, learning_rate=0.066, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.1, learning_rate=0.066, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.1, learning_rate=0.066, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.07100000000000001, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.07100000000000001, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.07100000000000001, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.07100000000000001, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.1, colsample_bytree=0.7, lambda=0.4, learning_rate=0.046, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.1, colsample_bytree=0.7, lambda=0.4, learning_rate=0.046, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.1, colsample_bytree=0.7, lambda=0.4, learning_rate=0.046, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.1, colsample_bytree=0.7, lambda=0.4, learning_rate=0.046, max_depth=6, min_child_weight=5, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=0.2, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=0.2, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=0.2, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=0.2, learning_rate=0.001, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.1, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.6, learning_rate=0.076, max_depth=4, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.6, learning_rate=0.076, max_depth=4, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.6, learning_rate=0.076, max_depth=4, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.6, learning_rate=0.076, max_depth=4, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.0, learning_rate=0.061, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.0, learning_rate=0.061, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.0, learning_rate=0.061, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.0, learning_rate=0.061, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.056, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.056, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.056, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.0, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.056, max_depth=6, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.8, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.08600000000000001, max_depth=7, min_child_weight=3, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.036000000000000004, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.036000000000000004, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.036000000000000004, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.036000000000000004, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.8, colsample_bytree=0.7, lambda=1.5, learning_rate=0.011, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# ...
# [CV 1/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.091, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.091, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.091, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.7000000000000001, learning_rate=0.091, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.036000000000000004, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.036000000000000004, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.036000000000000004, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.4, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.036000000000000004, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.8, learning_rate=0.016, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.8, learning_rate=0.016, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.8, learning_rate=0.016, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.5, colsample_bytree=0.7, lambda=0.8, learning_rate=0.016, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.9000000000000001, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.9000000000000001, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.9000000000000001, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.9000000000000001, colsample_bytree=0.7, lambda=0.6000000000000001, learning_rate=0.031, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=1.6, learning_rate=0.021, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=1.6, learning_rate=0.021, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=1.6, learning_rate=0.021, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=1.6, learning_rate=0.021, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=1.0, learning_rate=0.006, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=1.0, learning_rate=0.006, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=1.0, learning_rate=0.006, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.30000000000000004, colsample_bytree=0.7, lambda=1.0, learning_rate=0.006, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.011, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.011, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.011, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.011, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.9, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.9, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.9, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.7000000000000001, colsample_bytree=0.7, lambda=0.9, learning_rate=0.051000000000000004, max_depth=7, min_child_weight=4, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.076, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.076, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.076, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=1.7000000000000002, colsample_bytree=0.7, lambda=0.30000000000000004, learning_rate=0.076, max_depth=5, min_child_weight=2, n_estimators=500, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.9, colsample_bytree=0.7, lambda=1.5, learning_rate=0.096, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.9, colsample_bytree=0.7, lambda=1.5, learning_rate=0.096, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.9, colsample_bytree=0.7, lambda=1.5, learning_rate=0.096, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.9, colsample_bytree=0.7, lambda=1.5, learning_rate=0.096, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 1/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.0, learning_rate=0.066, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 2/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.0, learning_rate=0.066, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 3/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.0, learning_rate=0.066, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# [CV 4/4] END alpha=0.6000000000000001, colsample_bytree=0.7, lambda=1.0, learning_rate=0.066, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7;, score=nan total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/tommasosalvatori/Desktop/MIT/15.572 - Analytics Lab/ADI/analyticslab/2_models/clustering.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/tommasosalvatori/Desktop/MIT/15.572%20-%20Analytics%20Lab/ADI/analyticslab/2_models/clustering.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> xgb_grid.fit(X_train,
#       <a href='vscode-notebook-cell:/Users/tommasosalvatori/Desktop/MIT/15.572%20-%20Analytics%20Lab/ADI/analyticslab/2_models/clustering.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>          y_train)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1806, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1804 def _run_search(self, evaluate_candidates):
#    1805     """Search n_iter candidates from param_distributions"""
# -> 1806     evaluate_candidates(
#    1807         ParameterSampler(
#    1808             self.param_distributions, self.n_iter, random_state=self.random_state
#    1809         )
#    1810     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     868 elif len(out) != n_candidates * n_splits:
#     869     raise ValueError(
#     870         "cv.split and cv.get_n_splits returned "
#     871         "inconsistent results. Expected {} "
#     872         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     873     )
# --> 875 _warn_or_raise_about_fit_failures(out, self.error_score)
#     877 # For callable self.scoring, the return type is only know after
#     878 # calling. If the return type is a dictionary, the error scores
#     879 # can now be inserted with the correct key. The type checking
#     880 # of out will be done in `_insert_error_scores`.
#     881 if callable(self.scoring):
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 2000 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2000 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py", line 1051, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py", line 534, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#                     ^^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py", line 954, in _create_dmatrix
#     return QuantileDMatrix(
#            ^^^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 1528, in __init__
#     self._init(
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 1587, in _init
#     it.reraise()
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 575, in reraise
#     raise exc  # pylint: disable=raising-bad-type
#     ^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 556, in _handle_exception
#     return fn()
#            ^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 640, in <lambda>
#     return self._handle_exception(lambda: self.next(input_data), 0)
#                                           ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/data.py", line 1280, in next
#     input_data(**self.kwargs)
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/core.py", line 623, in input_data
#     new, cat_codes, feature_names, feature_types = _proxy_transform(
#                                                    ^^^^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/data.py", line 1315, in _proxy_transform
#     arr, feature_names, feature_types = _transform_pandas_df(
#                                         ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/data.py", line 490, in _transform_pandas_df
#     _invalid_dataframe_dtype(data)
#   File "/Users/tommasosalvatori/anaconda3/lib/python3.11/site-packages/xgboost/data.py", line 308, in _invalid_dataframe_dtype
#     raise ValueError(msg)
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:Region: object

# %%
best_params = xgb_grid.best_params_
best_score = xgb_grid.best_score_

# %%
best_params
# Out:
# {'subsample': 0.7,
#  'n_estimators': 200,
#  'min_child_weight': 2,
#  'max_depth': 4,
#  'learning_rate': 0.001,
#  'lambda': 0.5,
#  'colsample_bytree': 0.7,
#  'alpha': 0.30000000000000004}

# %%
best_score
# Out:
# -0.03734267958655807

# %%
new_xgb = xgb_grid.best_estimator_

# %%
from sklearn.metrics import r2_score
r2_score(new_xgb.predict(X_test), y_test)

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.tree import DecisionTreeRegressor

model_cart = DecisionTreeRegressor()
model_cart.fit(X_train, y_train)
r2_score(model_cart.predict(X_train), y_train)

# %%
r2_score(y_test, model_cart.predict(X_test))

# %%
n = 0
d = 0
y_pred =model_cart.predict(X_test)
y_train_mean = y_train.mean()
for i in range(len(y_test)):
    n += (y_test.iloc[i] - y_pred[i]) ** 2
    d += (y_test.iloc[i] - y_train_mean) ** 2
r_squared = 1 - n/d
print(r_squared)

# %%
y_pred=model_cart.predict(X_test)

# %%
new_df=pd.DataFrame({"pred":y_pred, "test":y_test})

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(25,20))
plot_tree(model_cart)
plt.show()

# %%
model_cart2 = DecisionTreeRegressor(max_depth=10, min_samples_leaf=5)
model_cart2.fit(X_train, y_train)
r2_score(model_cart2.predict(X_train), y_train)

# %%
n = 0
d = 0
y_pred2 =model_cart2.predict(X_test)
y_train_mean = y_train.mean()
for i in range(len(y_test)):
    n += (y_test.iloc[i] - y_pred2[i]) ** 2
    d += (y_test.iloc[i] - y_train_mean) ** 2
r_squared2 = 1 - n/d
print(r_squared2)

# %%
fig = plt.figure(figsize=(25,20))
plot_tree(model_cart2)
plt.show()

# %% [markdown]
# # Clustering
# ## "artificial" clustering

# %%
#standardize data
from sklearn.preprocessing import MinMaxScaler

# X_train.drop(["Region"], axis = 1, inplace = True) #why was region still there?
# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler to the data and transform it
X_train_normalized = scaler.fit_transform(X_train)

# Convert the array back to a DataFrame (optional, for better readability)
X_train_normalized = pd.DataFrame(X_train_normalized, columns=X_train.columns)

y_train_reshaped = y_train.values.reshape(-1, 1)

# Fit the scaler to the data and transform it
y_train_normalized = scaler.fit_transform(y_train_reshaped)

# Flatten the array back to 1D (if needed)
y_train_normalized = y_train_normalized.ravel()

# %%
#create clusters based only on "CompanySpend"
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

Z = linkage(y_train_normalized.reshape(-1, 1), method='ward')
clusters = fcluster(Z, t=8, criterion='maxclust')

# Add clusters to X_train
#X_train['cluster'] = clusters
#y_train["cluster"] = clusters

# %%
#Train a tree on X_train to classify the clusters built above (why is region still in the df??)
tree_clusters = DecisionTreeClassifier(max_depth=6, min_samples_leaf=10)
tree_clusters.fit(X_train, clusters)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=10)

# %%
#Visualize tree and performance metrics
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix

# Visualize the decision tree
plt.figure(figsize=(20,10))
plot_tree(tree_clusters, filled=True, feature_names=X_train.columns, class_names=str(np.unique(clusters)))
plt.show()
clusters_pred = tree_clusters.predict(X_train)

# %%
from sklearn.metrics import accuracy_score
import seaborn as sns

accuracy = accuracy_score(clusters, clusters_pred)
cm = confusion_matrix(clusters, clusters_pred)

plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

print(accuracy)
# Out:
# 0.9380346690679874

# %%
#return feature importance in the tree
tree = tree_clusters.tree_
# Get the feature names
feature_names = X_train.columns

# Find the features used for splitting
split_feature_indices = tree.feature

# Translate indices to feature names, excluding leaves (where feature index is -2)
split_features = [feature_names[i] if i >= 0 else "leaf" for i in split_feature_indices]

# Filter out the "leaf" entries and get unique feature names
split_feature_names = list(set([name for name in split_features if name != "leaf"]))

print(split_feature_names)
# Out:
# ['Revenue_2', 'SubMarket_Flash Cards/Drives', 'SubMarket_Connected Consumer', 'Cogs', 'SubMarket_Auto Powertrain', 'DevSpends', 'Revenue_1', 'SubMarket_Auto Infotainment', 'Market_Industrial', 'Cogs_1', 'Ebitda_2', 'SubMarketSpends', 'SubMarket_Infrastructure', 'SubMarket_HDD', 'Ebitda_1', 'Ebitda', 'Revenue', 'Market_Automotive', 'SubMarket_Power & Energy', 'Cogs_2', 'TotalSpend', 'SubMarket_Auto ADAS']

# %% [markdown]
# ### Weighted clustering

# %%
import sklearn
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("../../clean_data/final_df.csv", index_col=0)

# %%
df= pd.get_dummies(df, columns=["Device", "Market", "SubMarket"])
df.rename({"Value":"CompanySpend", "Spendings":"TotalSpend"}, axis=1, inplace=True)

# %%
scaler = MinMaxScaler()
df_train = df[(df.Year<=2022)]
df_train.drop(["Company", "Year", "Region"], axis=1, inplace=True)
df_train_normalized = scaler.fit_transform(df_train)
df_train_normalized = pd.DataFrame(df_train_normalized, columns = df_train.columns)
df_train_normalized_weighted = pd.DataFrame(df_train_normalized, columns = df_train.columns)
df_train_normalized_weighted['CompanySpend'] = df_train_normalized_weighted['CompanySpend'] * 10
# Out:
# /var/folders/px/tjlhxsg56bg6d74d3c4cnhrc0000gn/T/ipykernel_60791/4179761981.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.drop(["Company", "Year", "Region"], axis=1, inplace=True)

# %%
distance_matrix = pdist(df_train_normalized_weighted, metric='euclidean')
h_clust = linkage(distance_matrix, method='ward')

# %%
dendro = dendrogram(h_clust)

# %%
hc_dissim = pd.DataFrame({'k': np.arange(1, len(h_clust) + 1),'dissimilarity': np.flipud(h_clust[:, 2])})

# Create the scree plot
plt.figure(figsize=(10, 6))
plt.plot(hc_dissim['k'], hc_dissim['dissimilarity'], marker='o')
plt.title('Scree Plot')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Dissimilarity')
plt.xlim(0,20)
plt.grid(True)
plt.show()

# %%
clusters = fcluster(h_clust, t=10, criterion='maxclust')

# %%
tree_clusters = DecisionTreeClassifier(max_depth=6, min_samples_leaf=10)
tree_clusters.fit(df_train, clusters)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=10)

# %%
plt.figure(figsize=(20,10))
plot_tree(tree_clusters, filled=True, feature_names=df_train.columns.tolist(), class_names=np.unique(clusters).astype(str).tolist())
plt.show()
clusters_pred = tree_clusters.predict(df_train)

# %%
accuracy = accuracy_score(clusters, clusters_pred)
cm = confusion_matrix(clusters, clusters_pred)

plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

print(accuracy)
# Out:
# 0.950303917154435

# %%
#return feature importance in the tree
tree = tree_clusters.tree_
# Get the feature names
feature_names = df_train.columns

# Find the features used for splitting
split_feature_indices = tree.feature

# Translate indices to feature names, excluding leaves (where feature index is -2)
split_features = [feature_names[i] if i >= 0 else "leaf" for i in split_feature_indices]

# Filter out the "leaf" entries and get unique feature names
split_feature_names = list(set([name for name in split_features if name != "leaf"]))

print(split_feature_names)
# Out:
# ['TotalSpend', 'Device_Analog Application Specific IC', 'Market_Computer Platforms', 'SubMarketSpends', 'DevSpends', 'Market_Wireless Communications', 'Market_Computer Peripherals & Storage', 'MarketSpends', 'Market_Consumer']

# %%
new_df = pd.DataFrame(df_train, columns = df_train.columns)
new_df["clusters"] = clusters
cluster_df = pd.DataFrame({"CompanySpend" :new_df.CompanySpend, "clusters" : new_df.clusters})

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='clusters', y='CompanySpend', data=cluster_df)
plt.title('Box plot of CompanySpend by Cluster')
plt.ylim(0,40)
plt.show()
# Out:
# /Users/valentinpinon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/valentinpinon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/valentinpinon/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
